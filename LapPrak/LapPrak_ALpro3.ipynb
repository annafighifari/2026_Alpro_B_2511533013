# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **ALGORITMA & PEMOGRAMAN**
#
# **“PENGENALAN PYTHON, VS CODE, DAN KONEKSI KE GITHUB”**
#
# **Disusun Oleh :**
#
# **Annafi Al Ghifari**
#
# **2511533013**
#
# **Dosen Pengampu:**
#
# **DR. Wahyudi. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Galid Alvero**
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji dan syukur penulis panjatkan ke hadirat Allah SWT atas rahmat, taufik, dan hidayah-Nya, sehingga penulis dapat menyelesaikan laporan praktikum Algoritma dan Pemrograman (Alpro) Pertemuan 2 ini dengan baik dan tepat waktu.
#
# Laporan ini disusun sebagai salah satu syarat untuk memenuhi tugas Mata Kuliah Praktikum Algoritma dan Pemrograman pada Program Studi Sistem Informasi, Universitas Andalas. Adapun isi dari laporan ini mencakup pemahaman dasar mengenai pengenalan bahasa pemrograman Python, penggunaan fungsi luaran print(), penerapan komentar multi-baris, escape character, serta penggabungan teks (string concatenation).
#
# Dalam penyusunan laporan ini, penulis menyadari bahwa keberhasilan ini tidak lepas dari bantuan, bimbingan, dan dukungan dari berbagai pihak. Oleh karena itu, penulis ingin menyampaikan terima kasih yang sebesar-besarnya kepada:
#
# Dosen Pengampu Mata Kuliah Algoritma dan Pemrograman Universitas Andalas yang telah memberikan ilmu dan arahan selama proses pembelajaran.
#
# Asisten Laboratorium Praktikum Algoritma dan Pemrograman yang telah mendampingi, mengarahkan, dan memberikan panduan selama kegiatan praktikum berlangsung.
#
# Orang tua dan rekan-rekan mahasiswa yang selalu memberikan dukungan moral maupun material.
#
# Penulis menyadari bahwa dalam penyusunan laporan ini masih terdapat kekurangan dan jauh dari kata sempurna, baik dari segi penulisan maupun materi yang disajikan. Oleh karena itu, kritik dan saran yang membangun dari para pembaca sangat diharapkan demi perbaikan di masa yang akan datang.
#
# Akhir kata, semoga laporan praktikum ini dapat memberikan manfaat dan menambah wawasan bagi penulis khususnya serta pembaca pada umumnya.
#
# Padang, 09 September 2026

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Pemrograman komputer merupakan proses merancang dan membangun program komputer yang dapat mengeksekusi perintah tertentu. Sebagai langkah dasar dalam mempelajari bahasa pemrograman Python, pengenalan terhadap fungsi keluaran (output) serta pencetakan teks adalah materi paling fundamental. Pemahaman mengenai eksekusi kode secara sekuensial, penggunaan karakter lepas (escape character), pemformatan baris kosong, dan penggabungan teks (string concatenation) sangat mendasar agar praktikan memiliki pemahaman yang kuat dalam membangun struktur kode yang lebih kompleks di masa depan.
#
# ## 1.2 Tujuan
# 1. Memahami cara menggunakan fungsi contoh print().
# 2. Memahami implementasi komentar multi-baris menggunakan triple quotes contoh ("").
# 3. Mengetahui cara menggabungkan beberapa teks (string concatenation) menggunakan operator +.
#
# ## 1.3 Manfaat
# 1. Mampu menuliskan perintah dasar Python dengan sintaks yang benar.
# 2. Mampu menampilkan variasi luaran teks, termasuk simbol khusus dan penanganan baris kosong.
# 3. Dapat memberikan dokumentasi atau identitas pembuat program secara terstruktur pada kode sumber.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# Tuliskan penjelasan konsep/teori yang mendasari praktikum ini (definisi, elemen-elemen penting, dsb). Bisa memakai poin bernomor untuk merinci sub-konsep, contoh:
#
# 1. Poin konsep pertama
# Python adalah bahasa pemrograman tingkat tinggi (high-level programming language) yang bersifat interpreted dan dynamically typed. Python dirancang dengan fokus pada keterbacaan kode (code readability), sehingga sintaksnya sederhana dan intuitif dibandingkan dengan bahasa pemrograman tingkat tinggi lainnya.
# 2. Poin konsep kedua
# Fungsi print() merupakan salah satu built-in function utama dalam Python yang berfungsi untuk menampilkan data atau keluaran (output) ke media standar seperti terminal atau console.
#
# 3. Poin konsep ketiga
# Komentar adalah bagian dari kode yang diabaikan oleh interpreter saat program dieksekusi. Komentar bertujuan untuk memberikan dokumentasi atau penjelasan mengenai alur kode program.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "1_2511533013"
# Jalankan sel kode di bawah ini agar Jupyter otomatis menyimpan kodenya beserta outputnya sebagai satu kesatuan (tidak perlu screenshot terpisah untuk hasil run).

# %%
# aritmatika_2511533013.py
angka1_3013 = int(input("Input angka-1: "))
angka2_3013 = int(input("Input angka-2: "))

# penjumlahan
hasil_3013 = angka1_3013 + angka2_3013
print("\nOperator Penjumlahan")
print("Hasil =", hasil_3013)

# pengurangan
hasil_3013 = angka1_3013 - angka2_3013
print("\nOperator Pengurangan")
print("Hasil =", hasil_3013)

# perkalian
hasil_3013 = angka1_3013 * angka2_3013
print("\nOperator Perkalian")
print("Hasil =", hasil_3013)

# pembagian, pembagian bulat, dan sisa bagi
if angka2_3013 != 0:
    hasil_3013 = angka1_3013 / angka2_3013
    print("\nOperator Pembagian")
    print("Hasil =", hasil_3013)

    hasil_3013 = angka1_3013 // angka2_3013
    print("\nOperator Pembagian Bulat")
    print("Hasil =", hasil_3013)

    hasil_3013 = angka1_3013 % angka2_3013
    print("\nOperator Sisa bagi")
    print("Hasil =", hasil_3013)
else:
    print("Angka kedua tidak boleh bernilai 0.")

# pangkat
hasil_3013 = angka1_3013 ** angka2_3013
print("\nOperator Pangkat")
print("Hasil =", hasil_3013)
# Out:
# Operator Penjumlahan
# Hasil = 32
#
# Operator Pengurangan
# Hasil = 8
#
# Operator Perkalian
# Hasil = 240
#
# Operator Pembagian
# Hasil = 1.6666666666666667
#
# Operator Pembagian Bulat
# Hasil = 1
#
# Operator Sisa bagi
# Hasil = 8
#
# Operator Pangkat
# Hasil = 4096000000000000

# %% [markdown]
# **Penjelasan :**
# 1. Mengambil input dua angka dari pengguna yang dikonversi ke tipe data integer.
# 2. Menghitung operasi matematika dasar seperti penjumlahan, pengurangan, perkalian, dan perpangkatan.
# 3. Menggunakan kondisi if untuk mencegah error pembagian jika angka kedua bernilai 0.

# %%
# perbandingan_2511533013.py
#  program ini menggunakan fungsi input()
#  nilai yang dimasukkan akan dikonversi menjadi tipe data integer
#  program operator perbandingan dalam python

angka1_3013 = int(input("Input angka-1: "))
angka2_3013 = int(input("Input angka-2: "))

# lebih besar dari
hasil_3013 = angka1_3013 > angka2_3013
print("\nOperator Lebih Besar Dari")
print("angka1 > angka2 =", hasil_3013)

# lebih kecil dari
hasil_3013 = angka1_3013 < angka2_3013
print("\nOperator Lebih Kecil Dari")
print("angka1 < angka2 =", hasil_3013)

# lebih besar dari atau sama dengan
hasil_3013 = angka1_3013 >= angka2_3013
print("\nOperator Lebih Besar Dari atau Sama Dengan")
print("angka1 >= angka2 =", hasil_3013)

# lebih kecil dari atau sama dengan
hasil_3013 = angka1_3013 <= angka2_3013
print("\nOperator Lebih Kecil Dari atau Sama Dengan")
print("angka1 <= angka2 =", hasil_3013)

# sama dengan
hasil_3013 = angka1_3013 == angka2_3013
print("\nOperator Sama Dengan")
print("angka1 == angka2 =", hasil_3013)

# tidak sama dengan
hasil_3013 = angka1_3013 != angka2_3013
print("\nOperator Tidak Sama Dengan")
print("angka1 != angka2 =", hasil_3013)

# tambahan: perbandingan berantai dalam python
hasil_3013 = 0 < angka1_3013 < 100
print("\nOperator Perbandingan Berantai")
print("0 < angka1 < 100 =", hasil_3013)

hasil_3013 = 0 < angka2_3013 < 100
print("0 < angka2 < 100 =", hasil_3013)
# Out:
# Operator Lebih Besar Dari
# angka1 > angka2 = True
#
# Operator Lebih Kecil Dari
# angka1 < angka2 = False
#
# Operator Lebih Besar Dari atau Sama Dengan
# angka1 >= angka2 = True
#
# Operator Lebih Kecil Dari atau Sama Dengan
# angka1 <= angka2 = False
#
# Operator Sama Dengan
# angka1 == angka2 = False
#
# Operator Tidak Sama Dengan
# angka1 != angka2 = True
#
# Operator Perbandingan Berantai
# 0 < angka1 < 100 = True
# 0 < angka2 < 100 = True

# %% [markdown]
# **Penjelasan :**
# 1. Membandingkan dua angka menggunakan operator relasional dasar seperti >, <, >=, dan <=.
# 2. Memeriksa kesamaan dan ketidaksamaan nilai menggunakan operator == dan !=.
# 3. Menggunakan fitur perbandingan berantai (contoh: 0 < angka < 100) untuk mengecek rentang nilai sekaligus.

# %%
# logika_2511533013.py
# program ini menggunakan fungsi input()
# program operator logika dalam python

# memasukkan nilai boolean
# input tidak peka terhadap huruf kapital dan kecil
a1_3013 = input("Input nilai boolean-1 (True/False): ").strip().lower() == "true"
a2_3013 = input("Input nilai boolean-2 (True/False): ").strip().lower() == "true"

print("\nA1 =", a1_3013)
print("A2 =", a2_3013)

# konjungsi: bernailai True juka keduanya True
hasil_3013 = a1_3013 and a2_3013
print("\nOperator Konjungsi (AND)")
print("A1 and A2 =", hasil_3013)

# disjungsi: bernilai True jika salah satu True
hasil_3013 = a1_3013 or a2_3013
print("\nOperator Disjungsi (OR)")
print("A1 or A2 =", hasil_3013)

#  Negasi A1: membalik nilai A1
hasil_3013 = not a1_3013
print("\nOperator A1 (NOT)")
print("not A1 =", hasil_3013)

# Negasi A2: membalik nilai A2
hasil_3013 = not a2_3013
print("\nOperator A2 (NOT)")
print("not A2 =", hasil_3013)

# XOR: bernilai True jika kedua nilai berbeda
hasil_3013 = a1_3013 != a2_3013
print("\nDisjungsi Ekslusif (XOR)")
print("A1 XOR A2 =", hasil_3013)
# Out:
# A1 = True
# A2 = True
#
# Operator Konjungsi (AND)
# A1 and A2 = True
#
# Operator Disjungsi (OR)
# A1 or A2 = True
#
# Operator A1 (NOT)
# not A1 = False
#
# Operator A2 (NOT)
# not A2 = False
#
# Disjungsi Ekslusif (XOR)
# A1 XOR A2 = False

# %% [markdown]
# **Penjelasan :**
# 1. Menerima input teks True atau False dan mengonversinya menjadi nilai boolean.
# 2. Menguji logika dasar menggunakan operator and (konjungsi), or (disjungsi), dan not (negasi).
# 3. Menghitung logika XOR (disjungsi eksklusif) dengan membandingkan ketidaksamaan dua nilai (!=).

# %%
# assignment_2511533013.py
# program menggunakan fungsi input()
# nilai yang dimasukkan akan dikonversi menjadi tipedata integer
# program operator assignment dalam python

angka1_3013 = int(input("Input angka-1: "))
angka2_3013 = int(input("Input angka-2: "))

print("\nNilai awal angka1_3013=", angka1_3013)
print("\nNilai angka2=", angka2_3013)

# assignment biasa
hasil_3013 = angka1_3013
print("\nAssignment biasa (=)")
print("Hasil =", hasil_3013)

# Assignment penambahan
hasil_3013 = angka1_3013
hasil_3013 += angka2_3013
print("\nAssignment penambahan (+=)")
print("Hasil =", hasil_3013)

# Assignment pengurangan
hasil_3013 = angka1_3013
hasil_3013 -= angka2_3013
print("\nAssignment pengurangan (-=)")
print("Hasil_3013 =", hasil_3013)

# Assignment perkalian
hasil_3013 = angka1_3013
hasil_3013 *= angka2_3013
print("\nAssignment perkalian (*=)")
print("Hasil =", hasil_3013)

# Assignment pembagian, pembagian bulat, dan sisa bagi
if angka2_3013 != 0:
    hasil_3013 = angka1_3013
    hasil_3013 /= angka2_3013
    print("\nAssignment pembagian (/=)")
    print("Hasil =", hasil_3013)
    # operator tambahan
    hasil_3013 = angka1_3013
    hasil_3013 //= angka2_3013
    print("\nAssignment pembagian bulat (//=)")
    print("Hasil =", hasil_3013)
    hasil_3013 = angka1_3013
    hasil_3013 %= angka2_3013
    print("\nAssignment sisa bagi (%=)")
    print("Hasil =", hasil_3013)
else:
    print("\nPembagian tidak dapat dilakukan")
    print("Angka kedua tidak boleh bernilai 0")

# Operator tambahan: assignment perpangkatan
hasil_3013 = angka1_3013
hasil_3013 **= angka2_3013
print("\nAssignment perpangkatan (**=)")
print("hasil =", hasil_3013)
# Out:
# Nilai awal angka1_3013= 30
#
# Nilai angka2= 15
#
# Assignment biasa (=)
# Hasil = 30
#
# Assignment penambahan (+=)
# Hasil = 45
#
# Assignment pengurangan (-=)
# Hasil_3013 = 15
#
# Assignment perkalian (*=)
# Hasil = 450
#
# Assignment pembagian (/=)
# Hasil = 2.0
#
# Assignment pembagian bulat (//=)
# Hasil = 2
#
# Assignment sisa bagi (%=)
# Hasil = 0
#
# Assignment perpangkatan (**=)
# hasil = 14348907000000000000000

# %% [markdown]
# **Penjelasan :**
# 1. Menyimpan nilai awal dari input pengguna ke dalam variabel.
# 2. Menggunakan operator penugasan gabungan (seperti +=, -=, *=) untuk memperbarui nilai variabel secara langsung.
# 3. Menangani operasi pembagian, sisa bagi, dan perpangkatan dengan operator assignment khusus.

# %%
# lainnya_2511533013.py
# program ini memakai fungsi input()
# program operator keanggotaan dan identitas

print("/n========================")
print("1. OPERATOR KEANGGOTAAN")
print("========================")

# input beberapa data_3013 yg dipisahkan dgn koma
input_data_3013 = input("masukkan beberapa angka, pisahkan dengan koma:")

# mengubah input menjadi list integer
data_3013 = [int(angka_3013.strip()) for angka_3013 in input_data_3013.split(",")]

nilai_dicari_3013 = int(input("Masukkan angka yang ingin dicari:"))

# operator in
hasil_3013 = nilai_dicari_3013 in data_3013

# operator not in
hasil_3013 = nilai_dicari_3013 not in data_3013
print("\nOperator keanggotaan NOT IN")
print(nilai_dicari_3013, "not in", data_3013, "=", hasil_3013)

print("/n========================")
print("2. OPERATOR IDENTITAS")
print("========================")

# objek1 memakai list dari input pengguna
objek1_3013 = data_3013

# objek2 merujuk pada objek yang sama dengan objek1
objek2_3013 = data_3013

# objek3 memiliki isi sama, tapi merupakan objek baru
objek3_3013 = data_3013.copy()

print("objek1 =", objek1_3013)
print("objek2 =", objek2_3013)
print("objek3 =", objek3_3013)

# operator is
hasil_3013 = objek1_3013 is objek2_3013
print("\nOperator identitas IS")
print("objek1 is objek2 =", hasil_3013)

# operator is not
hasil_3013 = objek1_3013 is objek2_3013
print("\nOperator identitas IS NOT")
print("objek1 is not objek3 =", hasil_3013)

# membandingkan identitas dan nilai
print("\nPerbandingan identitas dan nilai")
print("objek1 is objek3 =", objek1_3013 is objek3_3013)
print("objek1 == objek3 =", objek1_3013 == objek3_3013)
# Out:
# /n========================
# 1. OPERATOR KEANGGOTAAN
# ...
#
# Operator keanggotaan NOT IN
# 50 not in [22, 19, 15, 31, 12] = True
# /n========================
# 2. OPERATOR IDENTITAS
# ...
# objek1 = [22, 19, 15, 31, 12]
# objek2 = [22, 19, 15, 31, 12]
# objek3 = [22, 19, 15, 31, 12]
#
# Operator identitas IS
# objek1 is objek2 = True
#
# Operator identitas IS NOT
# objek1 is not objek3 = True
#
# Perbandingan identitas dan nilai
# objek1 is objek3 = False
# objek1 == objek3 = True

# %% [markdown]
# **Penjelasan :**
# 1. Mengubah input teks berisi angka acak menjadi sebuah list bertipe integer.
# 2. Menguji keanggotaan nilai dalam list menggunakan operator not in.
# 3. Membandingkan alamat memori dan isi variabel menggunakan operator identitas (is, is not) serta perbandingan nilai (==).

# %%
# bitwise_2511533013.py
# program ini menggunakan fungsi input()

print("\n========================")
print("3. OPERATOR BITWISE")
print("========================")

angka1_3013 = int(input("Masukkan angka bitwise-1: "))
angka2_3013 = int(input("Masukkan angka bitwise-2: "))

print("\nAngka dalam bentuk desimal dan biner")
print("angka1 =", angka1_3013, "| biner =", bin(angka1_3013))
print("angka2 =", angka2_3013, "| biner =", bin(angka2_3013))

# bitwise AND
hasil_3013 = angka1_3013 & angka2_3013
print("\nBitwise AND (&)")
print(angka1_3013, "&", angka2_3013, "=", hasil_3013)
print("Biner hasil =", bin(hasil_3013))
print("Biner hasil (8 bit) =", format(hasil_3013, "08b"))

# bitwise XOR
hasil_3013 = angka1_3013 ^ angka2_3013
print("\nBitwise XOR (^)")
print(angka1_3013, "^", angka2_3013, "=", hasil_3013)
print("Biner hasil =", bin(hasil_3013))
print("Biner hasil (8 bit) =", format(hasil_3013, "08b"))

# bitwise NOT
hasil_3013 = ~angka1_3013
print("\nBitwise NOT (~)")
print("~", angka1_3013, "=", hasil_3013)
print("Biner hasil =", bin(hasil_3013))
print("Biner hasil (8 bit) =", format(hasil_3013, "08b"))

# bitwise geser kiri
jumlah_geser_3013 = int(input("\nMasukkan jumlah pergeseran bit: "))

hasil_3013 = angka1_3013 << jumlah_geser_3013
print("\nBitwise geser kanan (<<)")
print(angka1_3013, "<<", jumlah_geser_3013, "=", hasil_3013)
print("Biner hasil =", bin(hasil_3013))
print("Biner hasil (8 bit) =", format(hasil_3013, "08b"))

# bitwise geser kanan
hasil_3013 = angka1_3013 >> jumlah_geser_3013
print("\nBitwise geser kanan (>>)")
print(angka1_3013, ">>", jumlah_geser_3013, "=", hasil_3013)
print("Biner hasil =", bin(hasil_3013))
print("Biner hasil (8 bit) =", format(hasil_3013, "08b"))
# Out:
# ...
# 3. OPERATOR BITWISE
# ...
#
# Angka dalam bentuk desimal dan biner
# angka1 = 30 | biner = 0b11110
# angka2 = 19 | biner = 0b10011
#
# Bitwise AND (&)
# 30 & 19 = 18
# Biner hasil = 0b10010
# Biner hasil (8 bit) = 00010010
#
# Bitwise XOR (^)
# 30 ^ 19 = 13
# Biner hasil = 0b1101
# Biner hasil (8 bit) = 00001101
#
# Bitwise NOT (~)
# ~ 30 = -31
# Biner hasil = -0b11111
# Biner hasil (8 bit) = -0011111
#
# Bitwise geser kanan (<<)
# 30 << 2 = 120
# Biner hasil = 0b1111000
# Biner hasil (8 bit) = 01111000
#
# Bitwise geser kanan (>>)
# 30 >> 2 = 7
# Biner hasil = 0b111
# Biner hasil (8 bit) = 00000111

# %% [markdown]
# **Penjelasan :**
# 1. Mengonversi dan menampilkan angka desimal ke dalam bentuk biner (termasuk format 8-bit).
# 2. Melakukan operasi logika biner seperti AND (&), XOR (^), dan NOT (~).
# 3. Menggeser posisi bit ke kiri (<<) atau ke kanan (>>) berdasarkan jumlah pergeseran dari input.

# %% [markdown]
# ### 2.2.2 Program Driver "program1_2511533013"

# %%
# Tulis/tempel kode program driver di sini
# Out:
# The type of variable having value 100 is <class 'int'>
# The type of variable having value 10.2345 is <class 'float'>
# The type of variable having value (100+3j) is <class 'complex'>

# %% [markdown]
# Penjelasan program driver di atas: ...
#
# Jika hasil run program didapat dari IDE/terminal lain (bukan dari cell notebook ini), masukkan tangkapan layarnya seperti berikut (atur ukuran & posisi tengah):
#
# <div align="center">
# <img src="" width="400"><br>
# <em>Gambar 2.1 : Output Program</em>
# </div>

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal :**
# A. Instruksi Pengerjaan dan Pengumpulan
# 1.     File Program Python: Buatlah program Python yang menyelesaikan studi kasus terpadu dengan nama berkas tugas3_nim.py (ganti nim dengan nomor induk mahasiswa masing-masing).
# 2.     Laporan Praktikum: Susunlah laporan praktikum pekan 3 yang mendokumentasikan seluruh latihan praktikum serta penjelasan rinci alur logika program tugas dengan nama berkas LapPrak_ALpro3.ipynb.
# 3.     Penyimpanan di GitHub: Simpan kedua file tersebut ke dalam folder Pekan3 di dalam repositori praktikum masing-masing. Format repositori: 2026_PrakAlpro_[Kelas]_[NIM]. Lakukan tahapan staging, commit, dan push ke akun GitHub pribadi sebelum batas waktu pengumpulan berakhir.
# 4.     Template Laporan: Format penulisan laporan wajib mengikuti panduan dan template yang telah disediakan pada praktikum.
#
# B. Studi Kasus: Sistem Simulasi Transaksi dan Validasi Akses Toko
# Anda diminta untuk membuat sebuah program kasir sederhana yang digunakan untuk menghitung total transaksi pelanggan sekaligus melakukan pemeriksaan terhadap status pelanggan dan hak akses terhadap promo tertentu. Program menerima data transaksi dan informasi pelanggan, kemudian menggunakan berbagai jenis operator Python untuk menentukan total pembayaran, status diskon, kelayakan promo, serta hak akses pelanggan. Seluruh proses harus dibuat dalam satu alur program yang utuh.
#
#
# Ketentuan Teknis Program
#
#
# 1. Aturan Penamaan Variabel
#
# Setiap variabel yang dibuat wajib diakhiri dengan 4 digit terakhir NIM mahasiswa. Contoh jika NIM berakhiran 1234:
#
# nama_1234
#
# total_1234
#
# diskon_1234
#
# status_1234
#
# Penulisan variabel harus mematuhi kaidah case-sensitive dan tidak boleh menggunakan kata kunci bawaan Python (reserved keywords).
#
#
# 2. Data Pelanggan dan Transaksi
#
# Program harus meminta pengguna memasukkan:
#
# ·       Nama pelanggan
# ·       Status pelanggan (member / nonmember)
# ·       Total harga belanja
# ·       Jumlah barang
# ·       Kode promo
#
# Gunakan tipe data yang sesuai untuk setiap input. Contoh:
#
# Masukkan Nama Pelanggan : Caca
#
# Masukkan Status Pelanggan : member
#
# Masukkan Total Belanja : 250000
#
# Masukkan Jumlah Barang : 4
#
# Masukkan Kode Promo : HEMAT10
#
#
# 3. Operator Aritmatika
#
# Gunakan operator aritmatika untuk menghitung informasi transaksi, minimal meliputi:
#
# ·       Total harga setelah diskon
# ·       Harga rata-rata barang
# ·       Besarnya diskon
# ·       Sisa pembagian tertentu menggunakan operator %
#
# Program harus menggunakan lebih dari satu operator aritmatika.
#
#
# 4. Operator Perbandingan
#
# Gunakan operator perbandingan untuk menentukan apakah pelanggan memenuhi syarat mendapatkan diskon.
#
# ·       Belanja minimal Rp200.000 mendapatkan diskon.
# ·       Jumlah barang minimal 3 barang memenuhi syarat tambahan promo.
#
# Hasil perbandingan harus menghasilkan nilai True atau False.
#
#
# 5. Operator Logika
#
# Gunakan operator logika and, or, dan/atau not untuk menggabungkan beberapa kondisi. Contohnya, pelanggan mendapatkan diskon khusus apabila pelanggan merupakan member dan total belanja mencapai batas minimum. Buat minimal dua kondisi yang digabungkan menggunakan operator logika.
#
#
# 6. Operator Penugasan
#
# Gunakan operator penugasan, termasuk minimal satu operator augmented assignment, seperti:
#
# +=
#
# -=
#
# *=
#
# /=
#
# Contoh penerapan dapat digunakan untuk memperbarui total pembayaran atau jumlah poin pelanggan.
#
#
# 7. Operator Keanggotaan (Membership)
#
# Gunakan operator in dan not in untuk memeriksa apakah suatu kode promo terdapat dalam daftar kode promo yang tersedia.
#
# ["HEMAT10", "HEMAT20", "GRATISONGKIR"]
#
# Program harus menentukan apakah kode promo pelanggan tersedia atau tidak.
#
#
# 8. Operator Identitas (Identity)
#
# Gunakan operator is dan is not untuk menunjukkan perbedaan antara identitas objek dan kesamaan nilai. Program harus membuat minimal dua variabel/objek yang dapat digunakan untuk menunjukkan penggunaan operator is atau is not.
#
# Catatan: Mahasiswa harus dapat menjelaskan bahwa is digunakan untuk membandingkan identitas objek, sedangkan == digunakan untuk membandingkan nilai/isi objek.
#
#
# 9. Operator Bitwise
#
# Dalam sistem transaksi, setiap kondisi pelanggan akan direpresentasikan menggunakan bit biner untuk membentuk kode status transaksi.
#
# Gunakan aturan berikut:
#
#  | Nilai Bit | Kondisi
# | 0001 | Pelanggan merupakan member
# | 0010 | Total belanja ≥ Rp200.000
# | 0100 | Jumlah barang ≥ 3
# | 1000 | Kode promo tersedia
# Minimal gunakan tiga operator bitwise, yaitu:
#
# AND (&) untuk memeriksa apakah kondisi tertentu terpenuhi.
# OR (|) untuk menggabungkan beberapa kondisi transaksi.
# XOR (^) untuk membandingkan perbedaan status antara dua kode transaksi.
# C. Ketentuan Hasil Program
# Setelah seluruh input diproses, program harus menampilkan:
#
#
# DATA PELANGGAN
#
# ·       Nama pelanggan
# ·       Status pelanggan
# ·       Total belanja
# ·       Jumlah barang
# ·       Kode promo
#
#
# HASIL PERHITUNGAN
#
# ·       Besarnya diskon
# ·       Total pembayaran
# ·       Harga rata-rata barang
#
#
# HASIL VALIDASI
#
# ·       Apakah pelanggan memenuhi syarat minimum belanja?
# ·       Apakah jumlah barang memenuhi syarat?
# ·       Apakah pelanggan mendapatkan diskon member?
# ·       Apakah kode promo tersedia?
# ·       Apakah pelanggan mendapatkan promo?
# ·       Informasi hak akses pelanggan
#
#
# HASIL OPERATOR
#
# ·       Operator aritmatika
# ·       Operator perbandingan
# ·       Operator logika
# ·       Operator penugasan
# ·       Operator keanggotaan
# ·       Operator identitas
# ·       Operator bitwise
#
# D. Contoh Alur Eksekusi Program
# Berikut contoh gambaran tampilan program. Mahasiswa tidak diperbolehkan hanya menyalin contoh output; program harus dibuat berdasarkan logika yang telah ditentukan.
#
# E. Ketentuan Tambahan
# 1.     Program wajib menggunakan input dari pengguna, bukan seluruh nilai ditulis langsung di dalam program.
# 2.     Program harus menggunakan minimal satu contoh dari setiap jenis operator yang dibahas pada Modul Praktikum 3.
# 3.     Seluruh operator harus terintegrasi dalam satu studi kasus.
# 4.     Program harus dapat dijalankan tanpa error.
# 5.     Gunakan komentar pada bagian kode yang menunjukkan penerapan operator tertentu.
# 6.     Mahasiswa wajib memahami fungsi setiap operator yang digunakan dan mampu menjelaskan alur program pada laporan.
# 7.     Jangan menggunakan library tambahan yang belum dibahas dalam praktikum.
# 8.     Variabel wajib mengikuti aturan 4 digit terakhir NIM.
#
# F. Pertanyaan Analisis pada Laporan
# 1.     Jelaskan operator aritmatika apa saja yang digunakan dan bagaimana operator tersebut membantu menghitung transaksi.
# 2.     Jelaskan perbedaan operator and, or, dan not berdasarkan penerapannya pada program.
# 3.     Jelaskan fungsi operator in dan not in pada pemeriksaan kode promo.
# 4.     Apa perbedaan antara is dan == pada Python?
# 5.     Jelaskan bagaimana operator bitwise digunakan untuk menentukan hak akses pelanggan.
# 6.     Jelaskan alur program mulai dari input hingga menghasilkan total pembayaran dan status promo.
# 7.     Identifikasi minimal satu kondisi dalam program yang menghasilkan True dan satu kondisi yang menghasilkan False.
# </div>

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "Tugas3_2511533013"

# %%
print("=== SISTEM TRANSAKSI TOKO ===\n")

# 1. INPUT DATA PELANGGAN DAN TRANSAKSI
nama_3013 = input("Masukkan Nama Pelanggan : ")
status_3013 = input("Masukkan Status Pelanggan (member/nonmember) : ").strip().lower()
total_belanja_3013 = float(input("Masukkan Total Belanja : "))
jumlah_barang_3013 = int(input("Masukkan Jumlah Barang : "))
kode_promo_3013 = input("Masukkan Kode Promo : ").strip().upper()

# DAFTAR PROMO UNTUK OPERATOR MEMBERSHIP
daftar_promo_3013 = ["HEMAT10", "HEMAT20", "GRATISONGKIR"]

# 2. OPERATOR PERBANDINGAN & LOGIKA
is_min_belanja_3013 = total_belanja_3013 >= 200000
is_min_barang_3013 = jumlah_barang_3013 >= 3
is_member_3013 = status_3013 == "member"

promo_tersedia_3013 = kode_promo_3013 in daftar_promo_3013
promo_tidak_ada_3013 = kode_promo_3013 not in daftar_promo_3013

dapat_diskon_3013 = is_member_3013 and is_min_belanja_3013
dapat_promo_3013 = (is_min_barang_3013 or promo_tersedia_3013) and not promo_tidak_ada_3013

# 3. OPERATOR ARITMATIKA & ASSIGNMENT
persen_diskon_3013 = 0.10 if dapat_diskon_3013 else 0.0

besarnya_diskon_3013 = total_belanja_3013 * persen_diskon_3013
total_pembayaran_3013 = total_belanja_3013 - besarnya_diskon_3013
rata_rata_harga_3013 = total_belanja_3013 / jumlah_barang_3013
sisa_pembagian_3013 = jumlah_barang_3013 % 2  # Cek jumlah barang ganjil/genap

poin_3013 = 0
if dapat_promo_3013:
    poin_3013 += 50
    total_pembayaran_3013 -= 5000  # Potongan promo tambahan Rp5.000

# 4. OPERATOR IDENTITAS (is, is not)
objek_a_3013 = status_3013
objek_b_3013 = status_3013
objek_c_3013 = input_status_copy_3013 = str(status_3013)

cek_is_3013 = objek_a_3013 is objek_b_3013
cek_is_not_3013 = objek_a_3013 is not objek_c_3013

# 5. OPERATOR BITWISE
bit_member_3013 = 0b0001 if is_member_3013 else 0b0000
bit_belanja_3013 = 0b0010 if is_min_belanja_3013 else 0b0000
bit_barang_3013 = 0b0100 if is_min_barang_3013 else 0b0000
bit_promo_3013 = 0b1000 if promo_tersedia_3013 else 0b0000

status_biner_3013 = bit_member_3013 | bit_belanja_3013 | bit_barang_3013 | bit_promo_3013

cek_member_bitwise_3013 = status_biner_3013 & 0b0001
cek_promo_bitwise_3013 = status_biner_3013 & 0b1000

kode_referensi_3013 = 0b1011
perbandingan_xor_3013 = status_biner_3013 ^ kode_referensi_3013

geser_kiri_3013 = status_biner_3013 << 1

# OUTPUT UTAMA PROGRAM
print("\n=== DATA TRANSAKSI ===")
print(f"Nama Pelanggan        : {nama_3013}")
print(f"Status Pelanggan      : {status_3013}")
print(f"Total Belanja         : Rp{total_belanja_3013:.0f}")
print(f"Jumlah Barang         : {jumlah_barang_3013}")
print(f"Kode Promo            : {kode_promo_3013}")

print("\n=== HASIL VALIDASI ===")
print(f"Belanja >= Rp200000   : {is_min_belanja_3013}")
print(f"Jumlah Barang >= 3    : {is_min_barang_3013}")
print(f"Status Member         : {is_member_3013}")
print(f"Kode Promo Tersedia   : {promo_tersedia_3013}")
print(f"Mendapatkan Diskon    : {dapat_diskon_3013}")
print(f"Mendapatkan Promo     : {dapat_promo_3013}")

print("\n=== HASIL PERHITUNGAN ===")
print(f"Diskon                : Rp{besarnya_diskon_3013:.0f}")
print(f"Total Pembayaran      : Rp{total_pembayaran_3013:.0f}")
print(f"Rata-rata Harga Barang: Rp{rata_rata_harga_3013:.2f}")

print("\n=== HAK AKSES PELANGGAN ===")
print(f"Kode Hak Akses        : {bin(status_biner_3013)[2:].zfill(4)}")
print(f"Member Access         : {bool(cek_member_bitwise_3013)}")
print(f"Promo Access          : {bool(cek_promo_bitwise_3013)}")
print(f"Free Shipping Access  : {kode_promo_3013 == 'GRATISONGKIR'}")

print("\n=== OPERASI BITWISE ===")
print("=== Kode Status Transaksi ===")
print("0001 | 0010 | 0100 | 1000")
print(f"Kode Biner    : {bin(status_biner_3013)[2:].zfill(4)}")
print(f"Kode Desimal  : {status_biner_3013}")

print("\n=== Pemeriksaan Status ===")
print("Cek Member")
print(f"{bin(status_biner_3013)[2:].zfill(4)} & 0001")
print(f"Hasil Biner   : {bin(cek_member_bitwise_3013)[2:].zfill(4)}")
print(f"Hasil Desimal : {cek_member_bitwise_3013}")

print("\nCek Promo")
print(f"{bin(status_biner_3013)[2:].zfill(4)} & 1000")
print(f"Hasil Biner   : {bin(cek_promo_bitwise_3013)[2:].zfill(4)}")
print(f"Hasil Desimal : {cek_promo_bitwise_3013}")

print("\n=== Perbandingan Status ===")
print(f"Kode Transaksi : {bin(status_biner_3013)[2:].zfill(4)}")
print(f"Kode Referensi : {bin(kode_referensi_3013)[2:].zfill(4)}")
print(f"{bin(status_biner_3013)[2:].zfill(4)} ^ {bin(kode_referensi_3013)[2:].zfill(4)}")
print(f"Hasil Biner   : {bin(perbandingan_xor_3013)[2:].zfill(4)}")
print(f"Hasil Desimal : {perbandingan_xor_3013}")

print("\n=== Shift ===")
print(f"{bin(status_biner_3013)[2:].zfill(4)} << 1")
print(f"Hasil Biner   : {bin(geser_kiri_3013)[2:].zfill(5)}")
print(f"Hasil Desimal : {geser_kiri_3013}")

print("\n=== SELESAI ===")
# Out:
# === SISTEM TRANSAKSI TOKO ===
# === DATA TRANSAKSI ===
# Nama Pelanggan        : Annafi Al Ghifari
# Status Pelanggan      : member
# Total Belanja         : Rp210000
# Jumlah Barang         : 15
# Kode Promo            : HEMAT10
#
# === HASIL VALIDASI ===
# Belanja >= Rp200000   : True
# Jumlah Barang >= 3    : True
# Status Member         : True
# Kode Promo Tersedia   : True
# Mendapatkan Diskon    : True
# Mendapatkan Promo     : True
#
# === HASIL PERHITUNGAN ===
# Diskon                : Rp21000
# Total Pembayaran      : Rp184000
# Rata-rata Harga Barang: Rp14000.00
#
# === HAK AKSES PELANGGAN ===
# Kode Hak Akses        : 1111
# Member Access         : True
# Promo Access          : True
# Free Shipping Access  : False
#
# === OPERASI BITWISE ===
# === Kode Status Transaksi ===
# 0001 | 0010 | 0100 | 1000
# Kode Biner    : 1111
# Kode Desimal  : 15
#
# === Pemeriksaan Status ===
# Cek Member
# 1111 & 0001
# Hasil Biner   : 0001
# Hasil Desimal : 1
#
# Cek Promo
# 1111 & 1000
# ...

# %% [markdown]
# b. Kode Program Driver "_2511533013"

# %%
# Kode jawaban tugas bagian b (driver)

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/output_tugas.png" width="400"><br>
# <em>Gambar 2.3 : Output Tugas Praktikum</em>
# </div>
#
# **Penjelasan :** Program tugas ini ...

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan program yang telah dibuat, dapat disimpulkan bahwa fungsi print() pada Python digunakan untuk mencetak teks ke layar console. Karakter backslash (\) bertindak sebagai escape character, sehingga untuk menampilkan satu karakter \ pada output, dibutuhkan penulisan dua backslash (\\) di dalam kode. Selain itu, penggabungan beberapa string dapat dilakukan secara fleksibel menggunakan operator +.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Enterprise, J. (2019). Otodidak Pemrograman Python. Jakarta: PT Elex Media Komputindo.
#
# [2] Rossum, G. v., Drake, F. L., & FL, D. (2009). Python 3 Reference Manual. Scotts Valley, CA: CreateSpace.
